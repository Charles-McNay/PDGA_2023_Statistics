# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"PDGA Player Statistics.csv")
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#              Name  PDGA #  Rating  Year Gender Class        Division  \
# 0        K. Capps  168538     976  2023   Male   Pro  Mixed Pro Open
# 1       L. Samson   59419    1021  2023   Male   Pro  Mixed Pro Open
# 2        E. Keith   47472    1024  2023   Male   Pro  Mixed Pro Open
# 3  J. Hebenheimer   43762    1021  2023   Male   Pro  Mixed Pro Open
# 4      A. Marwede   75590    1032  2023   Male   Pro  Mixed Pro Open
# 5        P. Welck   39491    1007  2023   Male   Pro  Mixed Pro Open
# 6       A. Hammes   57365    1030  2023   Male   Pro  Mixed Pro Open
# 7       A. Barela   44382    1039  2023   Male   Pro  Mixed Pro Open
# 8        M. Welsh  166089     985  2023   Male   Pro  Mixed Pro Open
# 9      J. Courtis   56511    1010  2023   Male   Pro  Mixed Pro Open
#
#          Country State/Province  Events  Points     Cash
# 0  United States          Texas      16    1750   $1,315
# 1  United States       Illinois       3    1412   $2,394
# ...

# %%
len(df.index)
# Out:
# 4430

# %%
df.tail()
# Out:
#              Name  PDGA #  Rating  Year Gender Class           Division  \
# 4425    I. Piroth   13406     926  2023   Male   Pro      Mixed Pro 50+
# 4426    J. Hughes   35690     929  2023   Male   Pro      Mixed Pro 40+
# 4427      R. Bose  103885     821  2023   Male   Pro  Mixed Amateur 60+
# 4428     Z. North   69243     889  2023   Male   Pro    Mixed Amateur 2
# 4429  Q. Piekkola  255149     908  2023   Male   Pro  Mixed Amateur 40+
#
#             Country State/Province  Events  Points  Cash
# 4425  United States     California       1       0    NaN
# 4426  United States   Pennsylvania       1       0    NaN
# 4427  United States        Florida       1       0    NaN
# 4428  United States          Texas       1       0    NaN
# 4429  United States   South Dakota       1       0    NaN

# %%
df.describe()
# Out:
#               PDGA #       Rating    Year       Events       Points
# count    4430.000000  4430.000000  4430.0  4430.000000  4430.000000
# mean    95352.310609   917.366817  2023.0     1.574041    96.626637
# std     57306.592574   127.322448     0.0     1.046364   144.070785
# min        83.000000     0.000000  2023.0     1.000000     0.000000
# 25%     47139.250000   909.000000  2023.0     1.000000    16.000000
# 50%     91612.000000   941.000000  2023.0     1.000000    45.000000
# 75%    138329.250000   962.000000  2023.0     2.000000   110.000000
# max    255149.000000  1050.000000  2023.0    16.000000  1750.000000

# %%
data.isna().any()
# Out:
# Name              False
# PDGA #            False
# Rating            False
# Year              False
# Gender            False
# Class             False
# Division          False
# Country           False
# State/Province     True
# Events            False
# Points            False
#  Cash              True
# dtype: bool

# %%
df.drop(df.columns[[1, 3, 5]], axis=1, inplace=True)

# %%
df[' Cash ']
# Out:
# 0        $1,315
# 1        $2,394
# 2        $3,150
# 3        $1,754
# 4        $2,290
#           ...
# 4425         NaN
# 4426         NaN
# 4427         NaN
# 4428         NaN
# 4429         NaN
# Name:  Cash , Length: 4430, dtype: object

# %%
df[' Cash '] = df[' Cash '].str.replace(',', '')
df[' Cash '] = df[' Cash '].str.replace('$', '')
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_27652\3430188760.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[' Cash '] = df[' Cash '].str.replace('$', '')

# %%
df[' Cash ']
# Out:
# 0        1315
# 1        2394
# 2        3150
# 3        1754
# 4        2290
#          ...
# 4425       NaN
# 4426       NaN
# 4427       NaN
# 4428       NaN
# 4429       NaN
# Name:  Cash , Length: 4430, dtype: object

# %%
df[' Cash '] = df[' Cash '].fillna(0)

# %%
df[[' Cash ']] = df[[' Cash ']].astype('int64')
df[' Cash ']
# Out:
# 0       1315
# 1       2394
# 2       3150
# 3       1754
# 4       2290
#         ...
# 4425       0
# 4426       0
# 4427       0
# 4428       0
# 4429       0
# Name:  Cash , Length: 4430, dtype: int64

# %%
df.head()
# Out:
#              Name  Rating Gender        Division        Country  \
# 0        K. Capps     976   Male  Mixed Pro Open  United States
# 1       L. Samson    1021   Male  Mixed Pro Open  United States
# 2        E. Keith    1024   Male  Mixed Pro Open  United States
# 3  J. Hebenheimer    1021   Male  Mixed Pro Open  United States
# 4      A. Marwede    1032   Male  Mixed Pro Open  United States
#
#   State/Province  Events  Points   Cash
# 0          Texas      16    1750    1315
# 1       Illinois       3    1412    2394
# 2          Texas       5    1237    3150
# 3       Missouri       5    1140    1754
# 4       Michigan       2    1130    2290

# %%
df.columns
# Out:
# Index(['Name', 'Rating', 'Gender', 'Division', 'Country', 'State/Province',
#        'Events', 'Points', ' Cash '],
#       dtype='object')

# %%
pd.isnull(df)
# Out:
#        Name  Rating  Gender  Division  Country  State/Province  Events  \
# 0     False   False   False     False    False           False   False
# 1     False   False   False     False    False           False   False
# 2     False   False   False     False    False           False   False
# 3     False   False   False     False    False           False   False
# 4     False   False   False     False    False           False   False
# ...     ...     ...     ...       ...      ...             ...     ...
# 4425  False   False   False     False    False           False   False
# 4426  False   False   False     False    False           False   False
# 4427  False   False   False     False    False           False   False
# 4428  False   False   False     False    False           False   False
# 4429  False   False   False     False    False           False   False
#
#       Points   Cash
# 0      False   False
# 1      False   False
# 2      False   False
# 3      False   False
# ...

# %%
df
# Out:
#                 Name  Rating Gender           Division        Country  \
# 0           K. Capps     976   Male     Mixed Pro Open  United States
# 1          L. Samson    1021   Male     Mixed Pro Open  United States
# 2           E. Keith    1024   Male     Mixed Pro Open  United States
# 3     J. Hebenheimer    1021   Male     Mixed Pro Open  United States
# 4         A. Marwede    1032   Male     Mixed Pro Open  United States
# ...              ...     ...    ...                ...            ...
# 4425       I. Piroth     926   Male      Mixed Pro 50+  United States
# 4426       J. Hughes     929   Male      Mixed Pro 40+  United States
# 4427         R. Bose     821   Male  Mixed Amateur 60+  United States
# 4428        Z. North     889   Male    Mixed Amateur 2  United States
# 4429     Q. Piekkola     908   Male  Mixed Amateur 40+  United States
#
#      State/Province  Events  Points   Cash
# 0             Texas      16    1750    1315
# ...

# %%
duplicateRows = df[df.duplicated(['Name'])]
duplicateRows
# Out:
#              Name  Rating  Gender         Division        Country  \
# 165       T. Sien     969    Male   Mixed Pro Open  United States
# 186     M. Cathey     988    Male  Mixed Amateur 1  United States
# 187   S. Harrison     954    Male   Mixed Pro Open  United States
# 226     D. Moriel     951    Male   Mixed Pro Open  United States
# 231    C. Robbins     935    Male  Mixed Amateur 1  United States
# ...           ...     ...     ...              ...            ...
# 4405  D. Willhoit     890    Male    Mixed Pro 50+  United States
# 4413     D. Green     936    Male    Mixed Pro 40+  United States
# 4417    L. Dostal     865  Female  Women's Pro 50+  United States
# 4419    E. Dostal     943    Male    Mixed Pro 50+  United States
# 4426    J. Hughes     929    Male    Mixed Pro 40+  United States
#
#       State/Province  Events  Points   Cash
# 165            Texas      10     440     159
# 186          Arizona       2     415       0
# ...

# %%
df.drop_duplicates(keep=False)
# Out:
#                 Name  Rating Gender           Division        Country  \
# 0           K. Capps     976   Male     Mixed Pro Open  United States
# 1          L. Samson    1021   Male     Mixed Pro Open  United States
# 2           E. Keith    1024   Male     Mixed Pro Open  United States
# 3     J. Hebenheimer    1021   Male     Mixed Pro Open  United States
# 4         A. Marwede    1032   Male     Mixed Pro Open  United States
# ...              ...     ...    ...                ...            ...
# 4425       I. Piroth     926   Male      Mixed Pro 50+  United States
# 4426       J. Hughes     929   Male      Mixed Pro 40+  United States
# 4427         R. Bose     821   Male  Mixed Amateur 60+  United States
# 4428        Z. North     889   Male    Mixed Amateur 2  United States
# 4429     Q. Piekkola     908   Male  Mixed Amateur 40+  United States
#
#      State/Province  Events  Points   Cash
# 0             Texas      16    1750    1315
# ...

# %%
result = df.dtypes

print("Output:")
print(result)
# Out:
# Output:
# Name              object
# Rating             int64
# Gender            object
# Division          object
# Country           object
# State/Province    object
# Events             int64
# Points             int64
#  Cash              int64
# dtype: object

# %%
df['State/Province'] = df['State/Province'].fillna('Unknown')

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#                        Name  Rating  Gender             Division  \
# 0                  K. Capps     976    Male       Mixed Pro Open
# 1                 L. Samson    1021    Male       Mixed Pro Open
# 2                  E. Keith    1024    Male       Mixed Pro Open
# 3            J. Hebenheimer    1021    Male       Mixed Pro Open
# 4                A. Marwede    1032    Male       Mixed Pro Open
# 5                  P. Welck    1007    Male       Mixed Pro Open
# 6                 A. Hammes    1030    Male       Mixed Pro Open
# 7                 A. Barela    1039    Male       Mixed Pro Open
# 8                  M. Welsh     985    Male       Mixed Pro Open
# 9                J. Courtis    1010    Male       Mixed Pro Open
# 10               A. Gossage    1028    Male       Mixed Pro Open
# 11                C. Kramer    1022    Male       Mixed Pro Open
# 12                  C. Rock    1011    Male       Mixed Pro Open
# ...

# %%
pd.reset_option('display.max_rows')
df
# Out:
#                 Name  Rating Gender           Division        Country  \
# 0           K. Capps     976   Male     Mixed Pro Open  United States
# 1          L. Samson    1021   Male     Mixed Pro Open  United States
# 2           E. Keith    1024   Male     Mixed Pro Open  United States
# 3     J. Hebenheimer    1021   Male     Mixed Pro Open  United States
# 4         A. Marwede    1032   Male     Mixed Pro Open  United States
# ...              ...     ...    ...                ...            ...
# 4425       I. Piroth     926   Male      Mixed Pro 50+  United States
# 4426       J. Hughes     929   Male      Mixed Pro 40+  United States
# 4427         R. Bose     821   Male  Mixed Amateur 60+  United States
# 4428        Z. North     889   Male    Mixed Amateur 2  United States
# 4429     Q. Piekkola     908   Male  Mixed Amateur 40+  United States
#
#      State/Province  Events  Points   Cash
# 0             Texas      16    1750    1315
# ...

# %%
df.to_csv(index=False)
# Out:
# "Name,Rating,Gender,Division,Country,State/Province,Events,Points, Cash \r\nK. Capps,976,Male,Mixed Pro Open,United States,Texas,16,1750,1315\r\nL. Samson,1021,Male,Mixed Pro Open,United States,Illinois,3,1412,2394\r\nE. Keith,1024,Male,Mixed Pro Open,United States,Texas,5,1237,3150\r\nJ. Hebenheimer,1021,Male,Mixed Pro Open,United States,Missouri,5,1140,1754\r\nA. Marwede,1032,Male,Mixed Pro Open,United States,Michigan,2,1130,2290\r\nP. Welck,1007,Male,Mixed Pro Open,United States,California,3,1090,1168\r\nA. Hammes,1030,Male,Mixed Pro Open,United States,Wisconsin,2,1080,1130\r\nA. Barela,1039,Male,Mixed Pro Open,United States,Arizona,2,1080,2265\r\nM. Welsh,985,Male,Mixed Pro Open,United States,Texas,5,1060,792\r\nJ. Courtis,1010,Male,Mixed Pro Open,United States,California,3,1035,1957\r\nA. Gossage,1028,Male,Mixed Pro Open,United States,Colorado,2,1030,820\r\nC. Kramer,1022,Male,Mixed Pro Open,United States,Texas,3,1027,1611\r\nC. Rock,1011,Male,Mixed Pro Open,United States,Arizon
# ...
